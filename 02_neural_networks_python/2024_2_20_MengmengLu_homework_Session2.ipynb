# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline

import tensorflow as tf

import numpy
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
# repeating the data prep from the previous notebook
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# EDIT: splitting training data into train and val because this is better practice than using test data to
# choose models/hyperparameters
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.33, random_state=42)

x_train = x_train.astype(numpy.float32)
# EDIT: adding pre-processing to validation data 
x_val  = x_val.astype(numpy.float32)
x_test  = x_test.astype(numpy.float32)

x_train /= 255.
x_val  /= 255.
x_test  /= 255.

print(x_train.shape)
x_train = x_train.reshape(x_train.shape[0], numpy.prod(x_train[0,:,:].shape))
x_val = x_val.reshape(x_val.shape[0], numpy.prod(x_val[0,:,:].shape))
x_test = x_test.reshape(x_test.shape[0], numpy.prod(x_test[0,:,:].shape))

print(x_train.shape)
y_train = y_train.astype(numpy.int32)
y_val  = y_val.astype(numpy.int32)
y_test  = y_test.astype(numpy.int32)

print()
print('MNIST data loaded: train:',len(x_train),'val:',len(x_val), 'test:',len(x_test))
print('X_train:', x_train.shape)
print('y_train:', y_train.shape)

# one-hot encoding:
nb_classes = 10
y_train_onehot = tf.keras.utils.to_categorical(y_train, nb_classes)
y_val_onehot = tf.keras.utils.to_categorical(y_val, nb_classes)
y_test_onehot = tf.keras.utils.to_categorical(y_test, nb_classes)
# Out:
# (40200, 28, 28)
# (40200, 784)
#
# MNIST data loaded: train: 40200 val: 19800 test: 10000
# X_train: (40200, 784)
# y_train: (40200,)

# %%
# Here we import an implementation of a two-layer neural network 
# this code is based on pieces of the first assignment from Stanford's CSE231n course, 
# hosted at https://github.com/cs231n/cs231n.github.io with the MIT license
from fc_net import TwoLayerNet

# %%
# a simple implementation of stochastic gradient descent
def sgd(model, gradients, learning_rate):
    for p, w in model.params.items():
        dw = gradients[p]
        new_weights = w - learning_rate * dw
        model.params[p] = new_weights

# %%
# one training step
def learn(model, x_train, y_train_onehot, learning_rate):
    loss, gradients = model.loss(x_train, y_train_onehot)
    sgd(model, gradients, learning_rate)
    return loss

# %%
def accuracy(model, x, true_values):
    scores = model.loss(x)
    predictions = numpy.argmax(scores, axis=1)
    N = predictions.shape[0]
    # EDIT: squeezing true_values from 2d to 1d speeds up this function
    true_values_1d = numpy.squeeze(true_values)
    acc = (true_values_1d == predictions).sum() / N
    return acc

# %%
# EDIT: decided to track how long each epoch takes
import time

# %%
# Here's an example training loop using this two-layer model. Can you do better? 

# EDIT: also track validation data
# EDIT: factoring this out into a function to make it easier to compare options
def training(learning_rate, batch_size, num_epochs, hidden_dim, weight_scale, x_train, y_train, y_train_onehot, x_val, y_val, y_val_onehot):
    num_features = x_train.shape[1] # this is the number of pixels
    nb_classes = y_train_onehot.shape[1]
    
    # The weights are initialized from a normal distribution with standard deviation weight_scale
    model = TwoLayerNet(input_dim=num_features, hidden_dim=hidden_dim, num_classes=nb_classes, weight_scale=weight_scale)
    
    num_examples_train = x_train.shape[0]
    num_batches_train = int(num_examples_train / batch_size)
    
    losses = numpy.zeros((num_batches_train*num_epochs,2)) # 1st column for training data, 2nd for validation data
    # EDIT: also track accuracy
    accuracies = numpy.zeros((num_batches_train*num_epochs,2)) 
    
    indices_train = numpy.arange(num_examples_train)
    num_examples_val = x_val.shape[0]
    indices_val = numpy.arange(num_examples_val)

    i = 0
    for epoch in range(0, num_epochs):
        start_epoch = time.time()
        # in each epoch, we loop over all of the training examples
        for step in range(0, num_batches_train):
            # grabbing the next training batch
            offset_train = step * batch_size
            batch_range_train = range(offset_train, offset_train+batch_size)
            x_train_batch = x_train[batch_range_train, :]
            # EDIT: keep around non-onehot labels as well for accuracy calculation
            y_train_onehot_batch = y_train_onehot[batch_range_train,:]
            y_train_batch = y_train[batch_range_train,numpy.newaxis]

            # one approach: grab a random validation batch (random offset into number of validation examples)
            offset_val = numpy.random.randint(low=0, high=num_examples_val-batch_size)
            batch_range_val = range(offset_val, offset_val+batch_size)
            x_val_batch = x_val[batch_range_val, :]
            y_val_onehot_batch = y_val_onehot[batch_range_val,:]
            y_val_batch = y_val[batch_range_val,numpy.newaxis]

            # feed the next batch in to do one sgd step
            loss_train = learn(model, x_train_batch, y_train_onehot_batch, learning_rate)

            # check training & validation loss & accuracy
            losses[i,0] = loss_train
            
            # could save time by commenting out the next three lines and only tracking at the epoch level
            accuracies[i,0] = accuracy(model, x_train_batch, y_train_batch)
            losses[i,1], _ = model.loss(x_val_batch, y_val_onehot_batch)
            accuracies[i,1] = accuracy(model, x_val_batch, y_val_batch)
            i += 1

        # slower, so we're only doing this once per epoch: checking accuracy on all of the data at once
        acc_train = accuracy(model, x_train, y_train)
        acc_val = accuracy(model, x_val, y_val)
        
        # reshuffle the data so that we get a new set of batches
        numpy.random.shuffle(indices_train)
        x_train = x_train[indices_train,:]
        y_train = y_train[indices_train] # keep this shuffled the same way for use in accuracy calculation
        y_train_onehot = y_train_onehot[indices_train,:]

        numpy.random.shuffle(indices_val)
        x_val = x_val[indices_val,:]
        y_val = y_val[indices_val] 
        y_val_onehot = y_val_onehot[indices_val,:]
        end_epoch = time.time()
        time_this_epoch = end_epoch - start_epoch
        print("epoch %d took %.1f seconds, training loss %.5f (last batch), training accuracy %.3f, validation accuracy %.3f" % (epoch, time_this_epoch, loss_train, acc_train, acc_val))
    return losses, accuracies, model

# %%
# these are the hyperparameters we had in class
learning_rate = 0.01  
batch_size = 10000
num_epochs = 10
hidden_dim = 300
weight_scale = .01
losses, accuracies, model = training(learning_rate, batch_size, num_epochs, hidden_dim, weight_scale, x_train, y_train, y_train_onehot, x_val, y_val, y_val_onehot)

# EDIT: plot training & val, loss & accuracy
plt.figure()
plt.subplot(2,1,1)
plt.plot(losses[:,0])
plt.plot(losses[:,1])
plt.legend(["train", "val"])

plt.subplot(2,1,2)
plt.plot(accuracies[:,0])
plt.plot(accuracies[:,1])
# Out:
# epoch 0 took 1.2 seconds, training loss 2.30118 (last batch), training accuracy 0.136, validation accuracy 0.140
# epoch 1 took 1.1 seconds, training loss 2.30016 (last batch), training accuracy 0.155, validation accuracy 0.160
# epoch 2 took 1.1 seconds, training loss 2.29898 (last batch), training accuracy 0.180, validation accuracy 0.183
# epoch 3 took 1.2 seconds, training loss 2.29784 (last batch), training accuracy 0.209, validation accuracy 0.214
# epoch 4 took 1.1 seconds, training loss 2.29675 (last batch), training accuracy 0.247, validation accuracy 0.250
# epoch 5 took 1.1 seconds, training loss 2.29587 (last batch), training accuracy 0.285, validation accuracy 0.283
# epoch 6 took 1.0 seconds, training loss 2.29475 (last batch), training accuracy 0.317, validation accuracy 0.312
# epoch 7 took 1.1 seconds, training loss 2.29344 (last batch), training accuracy 0.347, validation accuracy 0.341
# epoch 8 took 1.1 seconds, training loss 2.29227 (last batch), training accuracy 0.373, validation accuracy 0.367
# epoch 9 took 1.1 seconds, training loss 2.29124 (last batch), training accuracy 0.396, validation accuracy 0.392

# %% [markdown]
# # Homework: improve the accuracy of this model.

# %% [markdown]
# Update this notebook so that the accuracy is improved. How high can you get it? You could change things directly in the notebook, such as increasing the number of epochs, changing the learning weight, changing the width of the hidden layer, etc. If you're more ambitious, you could also try changing the model definition itself by checking out the associated Python files. For example, you could add more layers to the network. The current notebook has a training accuracy of about 43%, but will vary with randomness.

# %%
# Here's an example network that is much more accurate. I experimented with each hyperparameter one at a time
# The training took about 11 seconds per epoch on my laptop, and the final validation accuracy was 94%
# It's much slower on ThetaGPU's single-gpu queue, since it doesn't take advantage of a GPU and is stuck using
# a portion of one of the node's CPUs. 
# (With some effort, you can convert everything to CuPy instead of NumPy and then it runs on the GPU)
# If you don't have your own computer to run on, you might want to use Google Colab. 
learning_rate = 0.1  
batch_size = 1200
num_epochs = 25
hidden_dim = 1600
# Try Xavier initialization, although need to use same scaling for both layers, so averaging
# https://keras.io/api/layers/initializers/
size_input = x_train.shape[1]
weight_scale1 = numpy.sqrt(2./(size_input+hidden_dim))
weight_scale2 = numpy.sqrt(2./(hidden_dim+nb_classes))
weight_scale = (weight_scale1 + weight_scale2)/2
print(weight_scale)
losses, accuracies, model = training(learning_rate, batch_size, num_epochs, hidden_dim, weight_scale, x_train, y_train, y_train_onehot, x_val, y_val, y_val_onehot)

plt.figure()
plt.subplot(2,1,1)
plt.plot(losses[:,0])
plt.plot(losses[:,1])
plt.legend(["train", "val"])

plt.subplot(2,1,2)
plt.plot(accuracies[:,0])
plt.plot(accuracies[:,1])
# Out:
# 0.03210479558034334
# epoch 0 took 4.5 seconds, training loss 0.68770 (last batch), training accuracy 0.851, validation accuracy 0.849
# epoch 1 took 4.4 seconds, training loss 0.56260 (last batch), training accuracy 0.876, validation accuracy 0.877
# epoch 2 took 4.5 seconds, training loss 0.45224 (last batch), training accuracy 0.889, validation accuracy 0.892
# epoch 3 took 4.5 seconds, training loss 0.38862 (last batch), training accuracy 0.897, validation accuracy 0.899
# epoch 4 took 4.5 seconds, training loss 0.35097 (last batch), training accuracy 0.901, validation accuracy 0.904
# epoch 5 took 4.5 seconds, training loss 0.33907 (last batch), training accuracy 0.906, validation accuracy 0.909
# epoch 6 took 4.5 seconds, training loss 0.38137 (last batch), training accuracy 0.911, validation accuracy 0.912
# epoch 7 took 4.5 seconds, training loss 0.35971 (last batch), training accuracy 0.914, validation accuracy 0.915
# epoch 8 took 4.6 seconds, training loss 0.32523 (last batch), training accuracy 0.916, validation accuracy 0.918
# epoch 9 took 4.6 seconds, training loss 0.27579 (last batch), training accuracy 0.918, validation accuracy 0.921
# epoch 10 took 4.5 seconds, training loss 0.28133 (last batch), training accuracy 0.921, validation accuracy 0.922
# epoch 11 took 4.5 seconds, training loss 0.26980 (last batch), training accuracy 0.923, validation accuracy 0.925
# epoch 12 took 4.6 seconds, training loss 0.32255 (last batch), training accuracy 0.925, validation accuracy 0.926
# epoch 13 took 4.5 seconds, training loss 0.25801 (last batch), training accuracy 0.928, validation accuracy 0.928
# epoch 14 took 4.6 seconds, training loss 0.27686 (last batch), training accuracy 0.929, validation accuracy 0.929
# epoch 15 took 4.5 seconds, training loss 0.25084 (last batch), training accuracy 0.931, validation accuracy 0.931
# epoch 16 took 4.5 seconds, training loss 0.30289 (last batch), training accuracy 0.933, validation accuracy 0.932
# epoch 17 took 4.5 seconds, training loss 0.19110 (last batch), training accuracy 0.934, validation accuracy 0.934
# epoch 18 took 4.6 seconds, training loss 0.23955 (last batch), training accuracy 0.936, validation accuracy 0.934
# epoch 19 took 4.6 seconds, training loss 0.24922 (last batch), training accuracy 0.937, validation accuracy 0.935
# epoch 20 took 4.5 seconds, training loss 0.22599 (last batch), training accuracy 0.938, validation accuracy 0.937
# epoch 21 took 4.5 seconds, training loss 0.22680 (last batch), training accuracy 0.939, validation accuracy 0.938
# epoch 22 took 4.5 seconds, training loss 0.19988 (last batch), training accuracy 0.941, validation accuracy 0.938
# epoch 23 took 4.5 seconds, training loss 0.21949 (last batch), training accuracy 0.942, validation accuracy 0.940
# epoch 24 took 4.5 seconds, training loss 0.20802 (last batch), training accuracy 0.943, validation accuracy 0.941

# %% [markdown]
# # Improvement test 1 ----> increasing epochs to 50

# %%
learning_rate = 0.1  
batch_size = 1200
num_epochs = 50
hidden_dim = 1600
# Try Xavier initialization, although need to use same scaling for both layers, so averaging
# https://keras.io/api/layers/initializers/
size_input = x_train.shape[1]
weight_scale1 = numpy.sqrt(2./(size_input+hidden_dim))
weight_scale2 = numpy.sqrt(2./(hidden_dim+nb_classes))
weight_scale = (weight_scale1 + weight_scale2)/2
print(weight_scale)
losses, accuracies, model = training(learning_rate, batch_size, num_epochs, hidden_dim, weight_scale, x_train, y_train, y_train_onehot, x_val, y_val, y_val_onehot)

plt.figure()
plt.subplot(2,1,1)
plt.plot(losses[:,0])
plt.plot(losses[:,1])
plt.legend(["train", "val"])

plt.subplot(2,1,2)
plt.plot(accuracies[:,0])
plt.plot(accuracies[:,1])
# Out:
# 0.03210479558034334
# epoch 0 took 4.5 seconds, training loss 0.68741 (last batch), training accuracy 0.848, validation accuracy 0.849
# epoch 1 took 4.5 seconds, training loss 0.53874 (last batch), training accuracy 0.877, validation accuracy 0.879
# epoch 2 took 4.5 seconds, training loss 0.44190 (last batch), training accuracy 0.891, validation accuracy 0.892
# epoch 3 took 4.5 seconds, training loss 0.37822 (last batch), training accuracy 0.898, validation accuracy 0.899
# epoch 4 took 4.5 seconds, training loss 0.37846 (last batch), training accuracy 0.903, validation accuracy 0.906
# epoch 5 took 4.5 seconds, training loss 0.32973 (last batch), training accuracy 0.907, validation accuracy 0.909
# epoch 6 took 4.5 seconds, training loss 0.32659 (last batch), training accuracy 0.911, validation accuracy 0.913
# epoch 7 took 4.4 seconds, training loss 0.33805 (last batch), training accuracy 0.914, validation accuracy 0.916
# epoch 8 took 4.4 seconds, training loss 0.30579 (last batch), training accuracy 0.917, validation accuracy 0.918
# epoch 9 took 4.4 seconds, training loss 0.29115 (last batch), training accuracy 0.919, validation accuracy 0.921
# epoch 10 took 4.5 seconds, training loss 0.29636 (last batch), training accuracy 0.922, validation accuracy 0.923
# epoch 11 took 4.4 seconds, training loss 0.27375 (last batch), training accuracy 0.923, validation accuracy 0.924
# epoch 12 took 4.4 seconds, training loss 0.25417 (last batch), training accuracy 0.924, validation accuracy 0.925
# epoch 13 took 4.4 seconds, training loss 0.24093 (last batch), training accuracy 0.927, validation accuracy 0.927
# epoch 14 took 4.4 seconds, training loss 0.24953 (last batch), training accuracy 0.930, validation accuracy 0.930
# epoch 15 took 4.4 seconds, training loss 0.25367 (last batch), training accuracy 0.932, validation accuracy 0.931
# epoch 16 took 4.4 seconds, training loss 0.24423 (last batch), training accuracy 0.933, validation accuracy 0.931
# epoch 17 took 4.4 seconds, training loss 0.24978 (last batch), training accuracy 0.934, validation accuracy 0.933
# epoch 18 took 4.4 seconds, training loss 0.31288 (last batch), training accuracy 0.935, validation accuracy 0.934
# epoch 19 took 4.4 seconds, training loss 0.18962 (last batch), training accuracy 0.938, validation accuracy 0.936
# epoch 20 took 4.4 seconds, training loss 0.22997 (last batch), training accuracy 0.938, validation accuracy 0.936
# epoch 21 took 4.4 seconds, training loss 0.22540 (last batch), training accuracy 0.939, validation accuracy 0.937
# epoch 22 took 4.4 seconds, training loss 0.20059 (last batch), training accuracy 0.940, validation accuracy 0.939
# epoch 23 took 4.4 seconds, training loss 0.21531 (last batch), training accuracy 0.941, validation accuracy 0.940
# epoch 24 took 4.4 seconds, training loss 0.21668 (last batch), training accuracy 0.943, validation accuracy 0.941
# epoch 25 took 4.4 seconds, training loss 0.22004 (last batch), training accuracy 0.943, validation accuracy 0.941
# epoch 26 took 4.4 seconds, training loss 0.21906 (last batch), training accuracy 0.945, validation accuracy 0.943
# epoch 27 took 4.4 seconds, training loss 0.17114 (last batch), training accuracy 0.946, validation accuracy 0.943
# epoch 28 took 4.4 seconds, training loss 0.18229 (last batch), training accuracy 0.946, validation accuracy 0.944
# epoch 29 took 4.4 seconds, training loss 0.20792 (last batch), training accuracy 0.947, validation accuracy 0.944
# epoch 30 took 4.4 seconds, training loss 0.18714 (last batch), training accuracy 0.948, validation accuracy 0.946
# epoch 31 took 4.4 seconds, training loss 0.19979 (last batch), training accuracy 0.948, validation accuracy 0.946
# epoch 32 took 4.4 seconds, training loss 0.20087 (last batch), training accuracy 0.950, validation accuracy 0.947
# epoch 33 took 4.4 seconds, training loss 0.21760 (last batch), training accuracy 0.950, validation accuracy 0.948
# epoch 34 took 4.4 seconds, training loss 0.17769 (last batch), training accuracy 0.951, validation accuracy 0.948
# epoch 35 took 4.4 seconds, training loss 0.17029 (last batch), training accuracy 0.952, validation accuracy 0.948
# epoch 36 took 4.4 seconds, training loss 0.16209 (last batch), training accuracy 0.953, validation accuracy 0.949
# epoch 37 took 4.5 seconds, training loss 0.15875 (last batch), training accuracy 0.953, validation accuracy 0.949
# epoch 38 took 4.4 seconds, training loss 0.15686 (last batch), training accuracy 0.954, validation accuracy 0.950
# epoch 39 took 4.4 seconds, training loss 0.18464 (last batch), training accuracy 0.955, validation accuracy 0.950
# epoch 40 took 4.4 seconds, training loss 0.17582 (last batch), training accuracy 0.956, validation accuracy 0.951
# epoch 41 took 4.4 seconds, training loss 0.16579 (last batch), training accuracy 0.956, validation accuracy 0.952
# epoch 42 took 4.4 seconds, training loss 0.14103 (last batch), training accuracy 0.957, validation accuracy 0.952
# epoch 43 took 4.4 seconds, training loss 0.13294 (last batch), training accuracy 0.957, validation accuracy 0.952
# epoch 44 took 4.4 seconds, training loss 0.13975 (last batch), training accuracy 0.958, validation accuracy 0.953
# epoch 45 took 4.4 seconds, training loss 0.15464 (last batch), training accuracy 0.958, validation accuracy 0.953
# epoch 46 took 4.4 seconds, training loss 0.15384 (last batch), training accuracy 0.959, validation accuracy 0.953
# epoch 47 took 4.4 seconds, training loss 0.14398 (last batch), training accuracy 0.960, validation accuracy 0.955
# epoch 48 took 4.4 seconds, training loss 0.14380 (last batch), training accuracy 0.960, validation accuracy 0.955
# epoch 49 took 4.4 seconds, training loss 0.14711 (last batch), training accuracy 0.961, validation accuracy 0.955

# %% [markdown]
# # Improvement test 2 ----> decreasing learning rate to 0.05

# %%
learning_rate = 0.05 
batch_size = 1200
num_epochs = 25
hidden_dim = 1600
# Try Xavier initialization, although need to use same scaling for both layers, so averaging
# https://keras.io/api/layers/initializers/
size_input = x_train.shape[1]
weight_scale1 = numpy.sqrt(2./(size_input+hidden_dim))
weight_scale2 = numpy.sqrt(2./(hidden_dim+nb_classes))
weight_scale = (weight_scale1 + weight_scale2)/2
print(weight_scale)
losses, accuracies, model = training(learning_rate, batch_size, num_epochs, hidden_dim, weight_scale, x_train, y_train, y_train_onehot, x_val, y_val, y_val_onehot)

plt.figure()
plt.subplot(2,1,1)
plt.plot(losses[:,0])
plt.plot(losses[:,1])
plt.legend(["train", "val"])

plt.subplot(2,1,2)
plt.plot(accuracies[:,0])
plt.plot(accuracies[:,1])
# Out:
# 0.03210479558034334
# epoch 0 took 4.4 seconds, training loss 1.07601 (last batch), training accuracy 0.810, validation accuracy 0.804
# epoch 1 took 4.4 seconds, training loss 0.75017 (last batch), training accuracy 0.846, validation accuracy 0.844
# epoch 2 took 4.5 seconds, training loss 0.57569 (last batch), training accuracy 0.864, validation accuracy 0.862
# epoch 3 took 4.5 seconds, training loss 0.50353 (last batch), training accuracy 0.876, validation accuracy 0.876
# epoch 4 took 4.5 seconds, training loss 0.44849 (last batch), training accuracy 0.883, validation accuracy 0.884
# epoch 5 took 4.5 seconds, training loss 0.46134 (last batch), training accuracy 0.889, validation accuracy 0.889
# epoch 6 took 4.5 seconds, training loss 0.40233 (last batch), training accuracy 0.892, validation accuracy 0.894
# epoch 7 took 4.5 seconds, training loss 0.41602 (last batch), training accuracy 0.896, validation accuracy 0.898
# epoch 8 took 4.4 seconds, training loss 0.37760 (last batch), training accuracy 0.898, validation accuracy 0.901
# epoch 9 took 4.5 seconds, training loss 0.38965 (last batch), training accuracy 0.901, validation accuracy 0.904
# epoch 10 took 4.4 seconds, training loss 0.33398 (last batch), training accuracy 0.904, validation accuracy 0.907
# epoch 11 took 4.5 seconds, training loss 0.35421 (last batch), training accuracy 0.906, validation accuracy 0.909
# epoch 12 took 4.5 seconds, training loss 0.33529 (last batch), training accuracy 0.908, validation accuracy 0.911
# epoch 13 took 4.5 seconds, training loss 0.34335 (last batch), training accuracy 0.909, validation accuracy 0.912
# epoch 14 took 4.5 seconds, training loss 0.33374 (last batch), training accuracy 0.911, validation accuracy 0.914
# epoch 15 took 4.5 seconds, training loss 0.29293 (last batch), training accuracy 0.913, validation accuracy 0.916
# epoch 16 took 4.5 seconds, training loss 0.31539 (last batch), training accuracy 0.913, validation accuracy 0.916
# epoch 17 took 4.5 seconds, training loss 0.30978 (last batch), training accuracy 0.916, validation accuracy 0.918
# epoch 18 took 4.5 seconds, training loss 0.32071 (last batch), training accuracy 0.917, validation accuracy 0.919
# epoch 19 took 4.5 seconds, training loss 0.29777 (last batch), training accuracy 0.918, validation accuracy 0.920
# epoch 20 took 4.5 seconds, training loss 0.27996 (last batch), training accuracy 0.919, validation accuracy 0.920
# epoch 21 took 4.5 seconds, training loss 0.29780 (last batch), training accuracy 0.921, validation accuracy 0.922
# epoch 22 took 4.5 seconds, training loss 0.30829 (last batch), training accuracy 0.922, validation accuracy 0.923
# epoch 23 took 4.5 seconds, training loss 0.25718 (last batch), training accuracy 0.923, validation accuracy 0.923
# epoch 24 took 4.5 seconds, training loss 0.25641 (last batch), training accuracy 0.924, validation accuracy 0.925

# %% [markdown]
# # Improvement test 3 ----> increasing learning rate to 0.3

# %%
learning_rate = 0.3
batch_size = 1200
num_epochs = 25
hidden_dim = 1600
# Try Xavier initialization, although need to use same scaling for both layers, so averaging
# https://keras.io/api/layers/initializers/
size_input = x_train.shape[1]
weight_scale1 = numpy.sqrt(2./(size_input+hidden_dim))
weight_scale2 = numpy.sqrt(2./(hidden_dim+nb_classes))
weight_scale = (weight_scale1 + weight_scale2)/2
print(weight_scale)
losses, accuracies, model = training(learning_rate, batch_size, num_epochs, hidden_dim, weight_scale, x_train, y_train, y_train_onehot, x_val, y_val, y_val_onehot)

plt.figure()
plt.subplot(2,1,1)
plt.plot(losses[:,0])
plt.plot(losses[:,1])
plt.legend(["train", "val"])

plt.subplot(2,1,2)
plt.plot(accuracies[:,0])
plt.plot(accuracies[:,1])
# Out:
# 0.03210479558034334
# epoch 0 took 4.5 seconds, training loss 0.40865 (last batch), training accuracy 0.880, validation accuracy 0.882
# epoch 1 took 4.5 seconds, training loss 0.35308 (last batch), training accuracy 0.896, validation accuracy 0.900
# epoch 2 took 4.6 seconds, training loss 0.26727 (last batch), training accuracy 0.915, validation accuracy 0.917
# epoch 3 took 4.7 seconds, training loss 0.29763 (last batch), training accuracy 0.922, validation accuracy 0.924
# epoch 4 took 4.8 seconds, training loss 0.28195 (last batch), training accuracy 0.928, validation accuracy 0.928
# epoch 5 took 4.6 seconds, training loss 0.23083 (last batch), training accuracy 0.934, validation accuracy 0.933
# epoch 6 took 4.7 seconds, training loss 0.24320 (last batch), training accuracy 0.938, validation accuracy 0.938
# epoch 7 took 4.6 seconds, training loss 0.20862 (last batch), training accuracy 0.942, validation accuracy 0.941
# epoch 8 took 4.6 seconds, training loss 0.18663 (last batch), training accuracy 0.944, validation accuracy 0.942
# epoch 9 took 4.7 seconds, training loss 0.19106 (last batch), training accuracy 0.947, validation accuracy 0.945
# epoch 10 took 4.6 seconds, training loss 0.17920 (last batch), training accuracy 0.951, validation accuracy 0.948
# epoch 11 took 4.6 seconds, training loss 0.16319 (last batch), training accuracy 0.952, validation accuracy 0.949
# epoch 12 took 4.7 seconds, training loss 0.17578 (last batch), training accuracy 0.955, validation accuracy 0.951
# epoch 13 took 4.5 seconds, training loss 0.13290 (last batch), training accuracy 0.957, validation accuracy 0.953
# epoch 14 took 4.7 seconds, training loss 0.15959 (last batch), training accuracy 0.958, validation accuracy 0.954
# epoch 15 took 4.6 seconds, training loss 0.12628 (last batch), training accuracy 0.961, validation accuracy 0.956
# epoch 16 took 4.6 seconds, training loss 0.16031 (last batch), training accuracy 0.961, validation accuracy 0.957
# epoch 17 took 4.6 seconds, training loss 0.16097 (last batch), training accuracy 0.964, validation accuracy 0.958
# epoch 18 took 4.6 seconds, training loss 0.13171 (last batch), training accuracy 0.964, validation accuracy 0.958
# epoch 19 took 4.6 seconds, training loss 0.11759 (last batch), training accuracy 0.966, validation accuracy 0.960
# epoch 20 took 4.8 seconds, training loss 0.13838 (last batch), training accuracy 0.967, validation accuracy 0.960
# epoch 21 took 4.6 seconds, training loss 0.10892 (last batch), training accuracy 0.969, validation accuracy 0.961
# epoch 22 took 4.7 seconds, training loss 0.10236 (last batch), training accuracy 0.970, validation accuracy 0.962
# epoch 23 took 4.5 seconds, training loss 0.13240 (last batch), training accuracy 0.971, validation accuracy 0.964
# epoch 24 took 4.7 seconds, training loss 0.10593 (last batch), training accuracy 0.972, validation accuracy 0.964

# %% [markdown]
# # Improvement test 4 ----> increasing hidden_dim to 2000

# %%
learning_rate = 0.1  
batch_size = 1200
num_epochs = 25
hidden_dim = 2000
# Try Xavier initialization, although need to use same scaling for both layers, so averaging
# https://keras.io/api/layers/initializers/
size_input = x_train.shape[1]
weight_scale1 = numpy.sqrt(2./(size_input+hidden_dim))
weight_scale2 = numpy.sqrt(2./(hidden_dim+nb_classes))
weight_scale = (weight_scale1 + weight_scale2)/2
print(weight_scale)
losses, accuracies, model = training(learning_rate, batch_size, num_epochs, hidden_dim, weight_scale, x_train, y_train, y_train_onehot, x_val, y_val, y_val_onehot)

plt.figure()
plt.subplot(2,1,1)
plt.plot(losses[:,0])
plt.plot(losses[:,1])
plt.legend(["train", "val"])

plt.subplot(2,1,2)
plt.plot(accuracies[:,0])
plt.plot(accuracies[:,1])
# Out:
# 0.02917341413238523
# epoch 0 took 5.8 seconds, training loss 0.67515 (last batch), training accuracy 0.853, validation accuracy 0.853
# epoch 1 took 5.6 seconds, training loss 0.51914 (last batch), training accuracy 0.879, validation accuracy 0.879
# epoch 2 took 5.5 seconds, training loss 0.41877 (last batch), training accuracy 0.891, validation accuracy 0.893
# epoch 3 took 5.4 seconds, training loss 0.37027 (last batch), training accuracy 0.897, validation accuracy 0.899
# epoch 4 took 5.5 seconds, training loss 0.34502 (last batch), training accuracy 0.901, validation accuracy 0.905
# epoch 5 took 5.6 seconds, training loss 0.32909 (last batch), training accuracy 0.906, validation accuracy 0.911
# epoch 6 took 5.4 seconds, training loss 0.36449 (last batch), training accuracy 0.910, validation accuracy 0.914
# epoch 7 took 5.6 seconds, training loss 0.29542 (last batch), training accuracy 0.914, validation accuracy 0.917
# epoch 8 took 5.5 seconds, training loss 0.32209 (last batch), training accuracy 0.916, validation accuracy 0.918
# epoch 9 took 5.4 seconds, training loss 0.30015 (last batch), training accuracy 0.918, validation accuracy 0.920
# epoch 10 took 5.5 seconds, training loss 0.27065 (last batch), training accuracy 0.921, validation accuracy 0.922
# epoch 11 took 5.5 seconds, training loss 0.24145 (last batch), training accuracy 0.924, validation accuracy 0.924
# epoch 12 took 5.5 seconds, training loss 0.23663 (last batch), training accuracy 0.925, validation accuracy 0.926
# epoch 13 took 5.6 seconds, training loss 0.23980 (last batch), training accuracy 0.927, validation accuracy 0.927
# epoch 14 took 5.5 seconds, training loss 0.30507 (last batch), training accuracy 0.929, validation accuracy 0.929
# epoch 15 took 5.7 seconds, training loss 0.24875 (last batch), training accuracy 0.931, validation accuracy 0.930
# epoch 16 took 5.6 seconds, training loss 0.24950 (last batch), training accuracy 0.932, validation accuracy 0.932
# epoch 17 took 5.7 seconds, training loss 0.24035 (last batch), training accuracy 0.933, validation accuracy 0.933
# epoch 18 took 5.5 seconds, training loss 0.24993 (last batch), training accuracy 0.935, validation accuracy 0.934
# epoch 19 took 5.6 seconds, training loss 0.27150 (last batch), training accuracy 0.936, validation accuracy 0.936
# epoch 20 took 5.5 seconds, training loss 0.20493 (last batch), training accuracy 0.937, validation accuracy 0.936
# epoch 21 took 5.6 seconds, training loss 0.23102 (last batch), training accuracy 0.938, validation accuracy 0.938
# epoch 22 took 5.6 seconds, training loss 0.23226 (last batch), training accuracy 0.940, validation accuracy 0.939
# epoch 23 took 5.7 seconds, training loss 0.24722 (last batch), training accuracy 0.940, validation accuracy 0.939
# epoch 24 took 5.7 seconds, training loss 0.22515 (last batch), training accuracy 0.942, validation accuracy 0.940
